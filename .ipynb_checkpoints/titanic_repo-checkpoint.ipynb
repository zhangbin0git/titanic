# %% [markdown]
# # 选择分析泰坦尼克号项目，首先了解titanic-data.csv数据集，这些数据可以回答的问题包括。

# %% [markdown]
# ## 1. 有哪些因素会让船上的人生还率更高？

# %% [markdown]
# 数据集中的因素包括：
# 1	Survived	生存	0 =否，1 =是
# 2	Pclass	票类	1 = 1，2 = 2，3 = 3
# 3	Sex	性别
# 4	Age	年龄
# 5	SibSp	泰坦尼克号上的兄弟姐妹/配偶
# 6	Parch	泰坦尼克号上的父母/孩子的数量
# 7	Ticket	票号
# 8	Fare	乘客票价
# 9	Cabin	客舱号码
# 10	Embarked	登船港口	C =瑟堡，Q =皇后镇，S =南安普敦
#
# ### 我分析可能的因素为1、性别  2、年龄   3、票类/票价   4.孩子有父母和女性有配偶或兄弟生还率将增大

# %%
# 导入相关包数据
# %pylab inline
import numpy as py
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# 导入数据集
data = pd.read_csv('titanic-data.csv')
data['Fare_1'] = ''
data['Age_1'] = ''

# %%
# 显示前三条数据
data.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                           Glynn, Miss. Mary Agatha  female   NaN      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male   NaN      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male   NaN      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male   NaN      0
# 46                                  Lennon, Mr. Denis    male   NaN      1
# 47                          O'Driscoll, Miss. Bridget  female   NaN      0
# 48                                Samaan, Mr. Youssef    male   NaN      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
#
#     Parch            Ticket      Fare        Cabin Embarked Fare_1 Age_1
# 0       0         A/5 21171    7.2500          NaN        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250          NaN        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500          NaN        S
# 5       0            330877    8.4583          NaN        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750          NaN        S
# 8       2            347742   11.1333          NaN        S
# 9       0            237736   30.0708          NaN        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500          NaN        S
# 13      5            347082   31.2750          NaN        S
# 14      0            350406    7.8542          NaN        S
# 15      0            248706   16.0000          NaN        S
# 16      1            382652   29.1250          NaN        Q
# 17      0            244373   13.0000          NaN        S
# 18      0            345763   18.0000          NaN        S
# 19      0              2649    7.2250          NaN        C
# 20      0            239865   26.0000          NaN        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292          NaN        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750          NaN        S
# 25      5            347077   31.3875          NaN        S
# 26      0              2631    7.2250          NaN        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792          NaN        Q
# 29      0            349216    7.8958          NaN        S
# 30      0          PC 17601   27.7208          NaN        C
# 31      0          PC 17569  146.5208          B78        C
# 32      0            335677    7.7500          NaN        Q
# 33      0        C.A. 24579   10.5000          NaN        S
# 34      0          PC 17604   82.1708          NaN        C
# 35      0            113789   52.0000          NaN        S
# 36      0              2677    7.2292          NaN        C
# 37      0        A./5. 2152    8.0500          NaN        S
# 38      0            345764   18.0000          NaN        S
# 39      0              2651   11.2417          NaN        C
# 40      0              7546    9.4750          NaN        S
# 41      0             11668   21.0000          NaN        S
# 42      0            349253    7.8958          NaN        C
# 43      2     SC/Paris 2123   41.5792          NaN        C
# 44      0            330958    7.8792          NaN        Q
# 45      0   S.C./A.4. 23567    8.0500          NaN        S
# 46      0            370371   15.5000          NaN        Q
# 47      0             14311    7.7500          NaN        Q
# 48      0              2662   21.6792          NaN        C
# 49      0            349237   17.8000          NaN        S

# %%
# 总人数
pepole_sum = data.count()['Name']
pepole_sum
# Out:
# 891

# %%
def fare_cmp(para):
    if para > 200:
        return 'A'
    elif para > 150:
        return 'B'
    elif para > 100:
        return 'C'
    elif para >50:
        return 'D'
    else:
        return 'E'

# %%
def age_cmp(para):
    if para < 12:
        return 'A'
    elif para < 18:
        return 'B'
    else:
        return 'C'

# %%
data['Fare_1'] = data['Fare'].map(fare_cmp)

# %%
data['Age_1']=data['Age'].map(age_cmp)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked Fare_1 Age_1
# 0        0         A/5 21171    7.2500          NaN        S      E     C
# 1        0          PC 17599   71.2833          C85        C      D     C
# 2        0  STON/O2. 3101282    7.9250          NaN        S      E     C
# 3        0            113803   53.1000         C123        S      D     C
# 4        0            373450    8.0500          NaN        S      E     C
# 5        0            330877    8.4583          NaN        Q      E     C
# 6        0             17463   51.8625          E46        S      D     C
# 7        1            349909   21.0750          NaN        S      E     A
# 8        2            347742   11.1333          NaN        S      E     C
# 9        0            237736   30.0708          NaN        C      E     B
# 10       1           PP 9549   16.7000           G6        S      E     A
# 11       0            113783   26.5500         C103        S      E     C
# 12       0         A/5. 2151    8.0500          NaN        S      E     C
# 13       5            347082   31.2750          NaN        S      E     C
# 14       0            350406    7.8542          NaN        S      E     B
# 15       0            248706   16.0000          NaN        S      E     C
# 16       1            382652   29.1250          NaN        Q      E     A
# 17       0            244373   13.0000          NaN        S      E     C
# 18       0            345763   18.0000          NaN        S      E     C
# 19       0              2649    7.2250          NaN        C      E     C
# 20       0            239865   26.0000          NaN        S      E     C
# 21       0            248698   13.0000          D56        S      E     C
# 22       0            330923    8.0292          NaN        Q      E     B
# 23       0            113788   35.5000           A6        S      E     C
# 24       1            349909   21.0750          NaN        S      E     A
# 25       5            347077   31.3875          NaN        S      E     C
# 26       0              2631    7.2250          NaN        C      E     C
# 27       2             19950  263.0000  C23 C25 C27        S      A     C
# 28       0            330959    7.8792          NaN        Q      E     C
# 29       0            349216    7.8958          NaN        S      E     C
# ..     ...               ...       ...          ...      ...    ...   ...
# 861      0             28134   11.5000          NaN        S      E     C
# 862      0             17466   25.9292          D17        S      E     C
# 863      2          CA. 2343   69.5500          NaN        S      D     C
# 864      0            233866   13.0000          NaN        S      E     C
# 865      0            236852   13.0000          NaN        S      E     C
# 866      0     SC/PARIS 2149   13.8583          NaN        C      E     C
# 867      0          PC 17590   50.4958          A24        S      D     C
# 868      0            345777    9.5000          NaN        S      E     C
# 869      1            347742   11.1333          NaN        S      E     A
# 870      0            349248    7.8958          NaN        S      E     C
# 871      1             11751   52.5542          D35        S      D     C
# 872      0               695    5.0000  B51 B53 B55        S      E     C
# 873      0            345765    9.0000          NaN        S      E     C
# 874      0         P/PP 3381   24.0000          NaN        C      E     C
# 875      0              2667    7.2250          NaN        C      E     B
# 876      0              7534    9.8458          NaN        S      E     C
# 877      0            349212    7.8958          NaN        S      E     C
# 878      0            349217    7.8958          NaN        S      E     C
# 879      1             11767   83.1583          C50        C      D     C
# 880      1            230433   26.0000          NaN        S      E     C
# 881      0            349257    7.8958          NaN        S      E     C
# 882      0              7552   10.5167          NaN        S      E     C
# 883      0  C.A./SOTON 34068   10.5000          NaN        S      E     C
# 884      0   SOTON/OQ 392076    7.0500          NaN        S      E     C
# 885      5            382652   29.1250          NaN        Q      E     C
# 886      0            211536   13.0000          NaN        S      E     C
# 887      0            112053   30.0000          B42        S      E     C
# 888      2        W./C. 6607   23.4500          NaN        S      E     C
# 889      0            111369   30.0000         C148        C      E     C
# 890      0            370376    7.7500          NaN        Q      E     C
#
# [891 rows x 14 columns]

# %%
def ratio(data_cache, key_col, live):
    # 返回key_col分类的live的比率，live为1为生存率，0为死,cata为具体类别
    result = []
    group_cache = data_cache.groupby([key_col, 'Survived'])
    cata_key = data_cache.groupby([key_col, 'Survived']).size().index.levels[0].values
    for i in cata_key:
        print '分类基数' + str(i) + ':' + str(group_cache.size()[i].sum())
        result.append(float(group_cache.size()[i, live]) / group_cache.size()[i].sum())
    print pd.Series(result, index=cata_key)
    return pd.Series(result, index=cata_key).plot(kind='bar')

# %%
# 分类中SEX类别生存率
ratio(data, 'Sex', 1)
# Out:
# 分类基数female:314
# 分类基数male:577
# female    0.742038
# male      0.188908
# dtype: float64

# %% [markdown]
# ## 分析
# 从上图中可以看出女性的生还率是男性的3.5倍还要多，所以猜测女性有更高的生还机会，猜测主要由于英国男人比较绅士，把生的机会让给女性。

# %%
# 分类中Fare类别生存率
ratio(data, 'Fare_1', 1)
# Out:
# 分类基数A:20
# 分类基数B:9
# 分类基数C:24
# 分类基数D:107
# 分类基数E:731
# A    0.700000
# B    0.666667
# C    0.791667
# D    0.654206
# E    0.318741
# dtype: float64

# %% [markdown]
# ## 分析
# 此为票价分析：
# 'A'>$200、'B'> $150、'C'>$100、'D'>$50、'E'<$50
# 从图中看到，购买高价位票的人员，生还比率高，购买票价大于$50的人员和购买更贵的票的人员比购买低于$50美元的人员的生还率高一倍。所以推断富有的人员生还率更高。

# %%
# 分类中Pclass类别生存率
ratio(data, 'Pclass', 1)
# Out:
# 分类基数1:216
# 分类基数2:184
# 分类基数3:491
# 1    0.629630
# 2    0.472826
# 3    0.242363
# dtype: float64

# %% [markdown]
# ## 分析
# 从数据看一二等仓的生还率较高，比三等仓分别高出2.6倍和2倍，所以推断富有的人生还率更高。

# %%
# 分类中Embarked类别生存率
ratio(data, 'Embarked', 1)
# Out:
# 分类基数C:168
# 分类基数Q:77
# 分类基数S:644
# C    0.553571
# Q    0.389610
# S    0.336957
# dtype: float64

# %% [markdown]
# ## 分析
# 不同的港口，生还率相近

# %%
# 分类中Age类别生存率,其中删除了Age==NaN的行
data_mu_age = data.dropna(subset = ['Age'])
ratio(data_mu_age, 'Age_1', 1)
# Out:
# 分类基数A:68
# 分类基数B:45
# 分类基数C:601
# A    0.573529
# B    0.488889
# C    0.381032
# dtype: float64

# %% [markdown]
# ## 分析
# A代表12岁以下孩子的生还率，B代表18岁以下，C代表18岁以上的人，12岁以下孩子的生还率是18岁以上人员的1.5倍，12到18岁的人员生还率又有减少。

# %%
def ratio_three(data_cache, key_1, key_2, key_3):
    # 返回key_col分类的live的比率，live为1为生存率，0为死,cata为具体类别
    result = []
    group_cache = data_cache.groupby([key_1, key_2, key_3, 'Survived'])
    cata_key = group_cache.size().index.values
    cata_key_1 = []
    for w in cata_key:
        if w[3]!=0L:
            cata_key_1.append(w)
    for i in cata_key_1:
        (a, b, c, d) = i
        print '分类基数' + str([a, b, c]) + ':' + str(group_cache.size()[a, b, c].sum())
        result.append(float(group_cache.size()[a, b, c, d]) / group_cache.size()[a, b, c].sum())
    return pd.Series(result, index=cata_key_1).plot(kind='bar')

# %%
ratio_three(data_mu_age, 'Pclass', 'Sex', 'Age_1')
# Out:
# 分类基数[1L, 'female', 'F']:7
# 分类基数[1L, 'female', 'G']:77
# 分类基数[1L, 'male', 'A']:3
# 分类基数[1L, 'male', 'F']:1
# 分类基数[1L, 'male', 'G']:97
# 分类基数[2L, 'female', 'A']:8
# 分类基数[2L, 'female', 'F']:4
# 分类基数[2L, 'female', 'G']:62
# 分类基数[2L, 'male', 'A']:9
# 分类基数[2L, 'male', 'G']:88
# 分类基数[3L, 'female', 'A']:23
# 分类基数[3L, 'female', 'F']:12
# 分类基数[3L, 'female', 'G']:67
# 分类基数[3L, 'male', 'A']:24
# 分类基数[3L, 'male', 'F']:19
# 分类基数[3L, 'male', 'G']:210

# %% [markdown]
# ## 结论：提出没有年龄的人员后，从图中看出富有的女性和孩子生还率高。
